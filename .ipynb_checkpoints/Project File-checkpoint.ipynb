# %% [markdown]
# #  -------> Data Analysis On Agriculture Data To Improve Crop Production <-------

# %% [markdown]
# ### 1) Import The Reqired Library

# %%
import pandas as pd                    
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 2) Reading Data In Tabular Formart

# %%
data_agri = pd.read_csv('C:/Users/nimis/Desktop/project/New/datafile (2).csv') # Calling agriculture data file

# %%
data_agri.head(10)  # Inspecting the first 10 rows
# Out:
#                Crop  Prod2011  Prod2012  Prod2013  Prod2014  Prod2015  \
# 0  Total Foodgrains     158.8     168.6     171.3     159.4     178.9
# 1              Rice     200.8     207.9     213.3     191.6     206.4
# 2             Wheat     131.6     136.4     140.1     140.3     150.8
# 3             Jowar     124.3     137.8     126.0     116.5     121.8
# 4             Bajra     136.4     161.5     143.9       NaN     167.9
# 5             Maize     198.8     249.6     259.8     220.1     286.0
# 6              Ragi      56.1      83.6      79.3      73.4      85.2
# 7     Small millets      53.9      61.9      50.0      42.9      82.0
# 8            Barley      88.1      79.3     112.0      89.9     110.3
# 9    Coarse Cereals     138.5     166.4     163.5       NaN     178.4
#
#    Area2011  Area2012  Area2013  Area2014  Area2015  Yield2011  Yield2012  \
# 0     128.5     128.8     127.6     126.0     131.7      123.6      130.9
# ...

# %%
data_agri.tail(5)   #Inspecting the last 5 rows
# Out:
#               Crop  Prod2011  Prod2012  Prod2013  Prod2014  Prod2015  \
# 50  Sweet potato        81.1      79.3      94.2      92.1      88.1
# 51           Onion     240.5     247.3     367.1     329.1     409.1
# 52        Banana       189.3     201.1     298.8     301.7     339.4
# 53       Sugarcane     149.8     146.7     120.1       NaN     144.3
# 54         Tobacco      88.1      83.6      96.4     105.3     140.9
#
#     Area2011  Area2012  Area2013  Area2014  Area2015  Yield2011  Yield2012  \
# 50      75.8      75.4      88.4      84.6      80.4      106.9      105.2
# 51     207.7     208.4     246.8     223.6     314.7      115.8      118.7
# 52     117.6     131.2     174.8     189.8     204.6      161.0      153.3
# 53     142.6     140.0     122.2     115.6     135.2      105.1      104.8
# 54      88.8      83.9      94.2     107.1     118.8       99.1       88.3
#
#     Yield2013  Yield2014  Yield2015    Weather  Season
# ...

# %%
type(data_agri)  #which type of DATA we are using --->  a) series    b)dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
data_agri.shape  #let's see how many rows & columns does this datasets have?
# Out:
# (55, 18)

# %%
data_agri.describe() #summary statistic // describing data in mean,std,min,max,25%,50%,75% //
# Out:
#           Prod2011     Prod2012     Prod2013     Prod2014     Prod2015  \
# count    55.000000    55.000000    55.000000    49.000000    55.000000
# mean    168.698182   182.629091   179.952727   179.432653   210.181818
# std     179.503163   199.671545   187.409253   194.113783   232.535985
# min      53.900000    54.400000    50.000000    42.900000    42.100000
# 25%     124.500000   122.200000   116.050000   111.800000   126.900000
# 50%     142.700000   160.100000   156.500000   150.700000   169.000000
# 75%     184.300000   200.100000   188.550000   197.500000   217.350000
# max    1427.700000  1571.500000  1463.000000  1430.300000  1790.600000
#
#          Area2011    Area2012    Area2013    Area2014    Area2015  \
# count   55.000000   55.000000   55.000000   55.000000   55.000000
# mean   116.025455  118.403636  120.530909  118.203636  127.216364
# std     37.990960   41.287797   44.460177   44.976615   54.842653
# ...

# %%
 data_agri.boxplot()
plt.xticks(rotation=90)
sns.set_style('darkgrid')                # With the help of box plot observing repeated and max values, unstable values

# %%
data_agri.info() #Checking the information in boxplot datatype and count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 18 columns):
# Crop         55 non-null object
# Prod2011     55 non-null float64
# Prod2012     55 non-null float64
# Prod2013     55 non-null float64
# Prod2014     49 non-null float64
# Prod2015     55 non-null float64
# Area2011     55 non-null float64
# Area2012     55 non-null float64
# Area2013     55 non-null float64
# Area2014     55 non-null float64
# Area2015     55 non-null float64
# Yield2011    55 non-null float64
# Yield2012    55 non-null float64
# Yield2013    55 non-null float64
# Yield2014    55 non-null float64
# Yield2015    55 non-null float64
# Weather      55 non-null object
# Season       55 non-null object
# dtypes: float64(15), object(3)
# memory usage: 7.9+ KB

# %% [markdown]
# # 3) Data Cleaning

# %%
data_agri.isnull()# Finding TRUE values for which has NaN data
# Out:
#      Crop  Prod2011  Prod2012  Prod2013  Prod2014  Prod2015  Area2011  \
# 0   False     False     False     False     False     False     False
# 1   False     False     False     False     False     False     False
# 2   False     False     False     False     False     False     False
# 3   False     False     False     False     False     False     False
# 4   False     False     False     False      True     False     False
# 5   False     False     False     False     False     False     False
# 6   False     False     False     False     False     False     False
# 7   False     False     False     False     False     False     False
# 8   False     False     False     False     False     False     False
# 9   False     False     False     False      True     False     False
# 10  False     False     False     False     False     False     False
# 11  False     False     False     False     False     False     False
# ...

# %%
data_agri.isnull().sum()           #check null value count as in production there are 6 null value
# Out:
# Crop         0
# Prod2011     0
# Prod2012     0
# Prod2013     0
# Prod2014     6
# Prod2015     0
# Area2011     0
# Area2012     0
# Area2013     0
# Area2014     0
# Area2015     0
# Yield2011    0
# Yield2012    0
# Yield2013    0
# Yield2014    0
# Yield2015    0
# Weather      0
# Season       0
# dtype: int64

# %%
data_agri[data_agri.Prod2015 > 1000] #checking unstable values that disturbing graph
# Out:
#             Crop  Prod2011  Prod2012  Prod2013  Prod2014  Prod2015  Area2011  \
# 38  Total Spices    1427.7    1571.5    1463.0    1430.3    1790.6     121.3
#
#     Area2012  Area2013  Area2014  Area2015  Yield2011  Yield2012  Yield2013  \
# 38     125.9     126.5     122.0     136.6     1176.6     1247.7     1156.8
#
#     Yield2014  Yield2015 Weather Season
# 38     1172.1     1310.8   Sunny   Rabi

# %%
data_agri.drop([38],inplace=True)                    # Droping unstable rows

# %%
data_agri[35:39]  # Check that selected row is droped or not
# Out:
#             Crop  Prod2011  Prod2012  Prod2013  Prod2014  Prod2015  Area2011  \
# 35          Tea      132.2     132.8     132.0     132.0     132.0     135.3
# 36       Coffee      138.0     139.8     139.9     154.5     161.1     117.9
# 37       Rubber      215.5     208.6     216.5       NaN     210.1      98.6
# 39  Black pepper     134.2      91.5      92.2      99.2     101.1     130.8
#
#     Area2012  Area2013  Area2014  Area2015  Yield2011  Yield2012  Yield2013  \
# 35     137.8     137.8     137.8     137.8       97.7       96.3       95.8
# 36     119.8     121.9     123.7     125.4      117.0      116.7      114.8
# 37     138.1     143.8     149.2     149.2      218.5      151.1      151.9
# 39     104.7     126.9     104.2      97.8      102.6       87.4       72.7
#
#     Yield2014  Yield2015    Weather  Season
# 35       95.8       95.8      Rainy    Rabi
# 36      125.0      128.5  Overcast   Kharif
# 37      140.9      140.9      Rainy    Rabi
# ...

# %%
data_agri.boxplot()
plt.xticks(rotation=90)                  # After droping unstable values boxplot is clear
sns.set_style('darkgrid')

# %%
data_agri[['Area2015','Prod2015']].plot.box()     #clear box plot for comparing area used for production

# %%
threshold = len(data_agri)*0.1
threshold
# Out:
# 5.4

# %% [markdown]
# # 4) Data Imputation And Manipulation

# %%
def impute_median(series):
    return series.fillna(series.median())    # function for filling null values

# %%
data_agri.Prod2014 = data_agri['Prod2014'].transform(impute_median)  #Transforming null values in median

# %%
data_agri.isnull().sum()                 # after transforming there is no null value
# Out:
# Crop         0
# Prod2011     0
# Prod2012     0
# Prod2013     0
# Prod2014     0
# Prod2015     0
# Area2011     0
# Area2012     0
# Area2013     0
# Area2014     0
# Area2015     0
# Yield2011    0
# Yield2012    0
# Yield2013    0
# Yield2014    0
# Yield2015    0
# Weather      0
# Season       0
# dtype: int64

# %%
data_agri.info()  #All columns have same number of rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 54
# Data columns (total 18 columns):
# Crop         54 non-null object
# Prod2011     54 non-null float64
# Prod2012     54 non-null float64
# Prod2013     54 non-null float64
# Prod2014     54 non-null float64
# Prod2015     54 non-null float64
# Area2011     54 non-null float64
# Area2012     54 non-null float64
# Area2013     54 non-null float64
# Area2014     54 non-null float64
# Area2015     54 non-null float64
# Yield2011    54 non-null float64
# Yield2012    54 non-null float64
# Yield2013    54 non-null float64
# Yield2014    54 non-null float64
# Yield2015    54 non-null float64
# Weather      54 non-null object
# Season       54 non-null object
# dtypes: float64(15), object(3)
# memory usage: 8.0+ KB

# %%
data_agri.describe() # Describing after cleaning and removing data
# Out:
#          Prod2011    Prod2012    Prod2013    Prod2014    Prod2015    Area2011  \
# count   54.000000   54.000000   54.000000   54.000000   54.000000   54.000000
# mean   145.383333  156.909259  156.192593  152.659259  180.914815  115.927778
# std     48.664387   59.594109   64.413850   63.186059   84.224028   38.340719
# min     53.900000   54.400000   50.000000   42.900000   42.100000   47.900000
# 25%    124.400000  119.500000  114.025000  116.975000  124.350000   92.125000
# 50%    141.650000  158.450000  154.350000  146.950000  168.700000  119.500000
# 75%    177.900000  197.775000  185.250000  189.775000  212.875000  131.175000
# max    253.200000  313.800000  367.100000  329.100000  409.100000  222.700000
#
#          Area2012    Area2013    Area2014    Area2015   Yield2011   Yield2012  \
# count   54.000000   54.000000   54.000000   54.000000   54.000000   54.000000
# mean   118.264815  120.420370  118.133333  127.042593  127.759259  133.516667
# ...

# %% [markdown]
# # 5) Visualization

# %%
grp = data_agri.groupby('Crop')                     #Grouping crop with production for comparing production and area
x = grp['Prod2015'].agg(np.mean)
y = grp['Area2015'].agg(np.mean)
z = grp['Yield2015'].agg(np.mean)

print(x)
print(y)
print(z)
# Out:
# Crop
# Arecanut                     184.3
# Arhar                        119.9
# Bajra                        167.9
# Banana                       339.4
# Barley                       110.3
# Black pepper                 101.1
# Cardamom                     162.2
# Castor seed                  220.9
# Cereals                      183.1
# Coarse Cereals               178.4
# Coconut                       97.7
# Coffee                       161.1
# Coriander                    261.3
# Cotton seed                  271.3
# Cotton(lint)                 310.8
# Dry chilies                  160.9
# Dry ginger                   368.1
# Garlic                       308.2
# Gram                         182.5
# Groundnut                    195.7
# Jowar                        121.8
# Jute                         213.8
# Jute & Mesta                 189.1
# Linseed                       48.8
# Maize                        286.0
# Mesta                         52.2
# ...

# %%
plt.figure(figsize=(20,6))                       # comparing area and production
plt.plot(x,color = 'r')        # Group wise Production for 2015
plt.plot(y, color = 'g')       # Group wise Area for 2015
plt.plot(z, color = 'b')       # Group wise Yeild for 2015
plt.title("Comparison")
plt.xticks(rotation=90)
sns.set_style('darkgrid')
plt.ylabel("Production---Area--->")
plt.xlabel("Crop------>")
plt.show()

# %%
sns.distplot(data_agri['Prod2015'],kde= True,bins= 20)    #Production rate from dataset
sns.set_style('darkgrid')

# %%
sns.jointplot(x='Prod2015',y='Area2015',color='green',
              data=data_agri,kind='hex')                             # Area used per production with help of jointplot as -
sns.set_style('darkgrid')                                                               # we can see density in graph

# %%
sns.jointplot(x='Prod2015',y='Area2015',data=data_agri,kind='reg')      # Area used per production with help of jointplot svm
sns.set_style('darkgrid')

# %%
sns.jointplot(x='Prod2015',y='Area2015',data=data_agri,kind='resid')   
sns.set_style('darkgrid')

# %%
sns.pairplot(data_agri)                                                                       # cross cheacking of col and row
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(20,5))                                                # over all production for crops for start year to end 
plt.xticks(rotation=90)
sns.set_style('darkgrid')
sns.barplot(x='Crop',y='Prod2015',data=data_agri)

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='Crop',y='Yield2015',data=data_agri)                                                          #,palette='coolwarm'
sns.set_style('darkgrid')
plt.xticks(rotation=90)
plt.show()                                                                #production per year and area used for the production

plt.figure(figsize=(20,6))
sns.barplot(x='Crop',y='Area2015',data=data_agri,palette='coolwarm')
sns.set_style('darkgrid')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(50,6))                 # Weather wise crop Production by using voilinplot
plt.xticks(rotation=90)
sns.set_style('darkgrid')
sns.violinplot(x = 'Weather',y='Prod2015',data = data_agri ,hue ='Season')
plt.legend(loc='center left',bbox_to_anchor=(1.0,0.5))

# %%
plt.figure(figsize=(45,5))                                                        # Season wise crop production by using barplot
plt.xticks(rotation=90)
sns.set_style('darkgrid')
sns.barplot(x = 'Crop',y='Prod2015',data = data_agri,hue= 'Season')
plt.legend(loc='center left',bbox_to_anchor=(1.0,0.5))

# %%
hmap = data_agri.pivot_table(index='Crop',columns='Weather',values='Prod2015')
plt.figure(figsize=(15,6))
                                                            # Heat map showing district wise growth of crop production on scale 
sns.set_style('darkgrid')
sns.heatmap(hmap,linecolor='White',linewidths=1,cmap='magma')

# %%
fp = data_agri.pivot_table(index='Crop',columns='Season',values='Area2015')
plt.figure(figsize=(15,6))
                                                                         # Area Used for the crop production in different season
sns.set_style('darkgrid')                    
sns.heatmap(fp,linecolor='white',linewidths=1,cmap='magma')

# %%
pf = data_agri.pivot_table(index='Crop',columns='Area2015',values='Prod2015')
plt.figure(figsize=(40,10))
                                                            # Area used for perticular crop and repesenting peroduction on scale
sns.set_style('darkgrid')
sns.heatmap(pf,cmap='magma',linecolor='white',linewidths=1)

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(data_agri,col='Season',row='Weather')                                    #Production as per seasons vs Weather
g.map(sns.distplot,'Prod2015')

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(data_agri,col='Season',row='Weather')                                        # Area as per seasons vs Weather
g.map(sns.distplot,'Area2015')

# %%
sns.heatmap(data_agri.corr(),annot=False)

# %% [markdown]
# # MODEL FOR GIVEN DATASET
#
# ## (1) Using Linear Regression Algorithm --:
#
# ## Training and Testing Data
#
# Now that we've explored the data a bit, let's go ahead and split the data into training and testing sets.
# ** Set a variable X equal to the numerical features area & Year and a variable y equal to the "Production" column. **

# %%
data_agri.columns
# Out:
# Index(['Crop', 'Prod2011', 'Prod2012', 'Prod2013', 'Prod2014', 'Prod2015',
#        'Area2011', 'Area2012', 'Area2013', 'Area2014', 'Area2015', 'Yield2011',
#        'Yield2012', 'Yield2013', 'Yield2014', 'Yield2015', 'Weather',
#        'Season'],
#       dtype='object')

# %%
X = data_agri[['Area2011', 'Area2012', 'Area2013', 'Area2014', 'Area2015', 'Yield2011',
       'Yield2012', 'Yield2013', 'Yield2014', 'Yield2015']]

# %%
y = data_agri['Prod2015']

# %% [markdown]
# ** Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size=0.3 and random_state=101**

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ## Training the Model
#
# Now its time to train our model on our training data!
#
# ** Import LinearRegression from sklearn.linear_model **

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **Create an instance of a LinearRegression() model named lm.**

# %%
lm = LinearRegression()

# %% [markdown]
# ## Train/fit lm on the training data.

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm.intercept_)
# Out:
# -148.13482733329062

# %% [markdown]
# **Print out the coefficients of the model**

# %%
lm.coef_
# Out:
# array([ 0.11092061, -0.72223559,  0.32152374, -0.0730546 ,  1.68124805,
#        -0.01189024,  0.52811124, -0.02870117, -0.20933019,  0.84077803])

# %% [markdown]
# ## Predicting Test Data
# Now that we have fit our model, let's evaluate its performance by predicting off the test values!
#
# ** Use lm.predict() to predict off the X_test set of the data.**

# %%
prediction = lm.predict(X_test)

# %%
prediction
# Out:
# array([153.9611663 , 210.63521195, 175.3376033 , 201.30755544,
#        157.27937752, 197.02536397, 174.18929912, 168.85086999,
#        291.31208068, 149.15653384,  34.04883276,  62.24639689,
#        452.04315097, 336.81086331, 213.59149245,  24.65977466,
#        142.60359869])

# %% [markdown]
# ### Create a scatterplot of the real test values versus the predicted values.

# %%
plt.scatter(y_test,prediction)
plt.xlabel('Y_test')                        
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
 sns.distplot((y_test-prediction))                                         #

# %% [markdown]
# ## Evaluating the Model
#
# Let's evaluate our model performance by calculating the residual sum of squares and the explained variance score (R^2).
#
# ** Calculate the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error. Refer to the lecture or to Wikipedia for the formulas**

# %%
from sklearn import metrics

# %%
print('MAE -->',metrics.mean_absolute_error(y_test,prediction))
print('MSE -->',metrics.mean_squared_error(y_test,prediction))
print('RMSE -->',np.sqrt(metrics.mean_squared_error(y_test,prediction)))
# Out:
# MAE --> 12.871013097611144
# MSE --> 361.61847077867134
# RMSE --> 19.016268581892486

# %%
metrics.explained_variance_score(y_test,prediction)                     #As we can see our model explan 96% variance
# Out:
# 0.960601428159721

# %% [markdown]
# ## Conclusion
# We still want to figure out the answer to the original question by using different algo for this dataset, we can interpret the coefficients at all to get an idea.
#
# ** Recreate the dataframe below. **

# %%
X_train.columns
# Out:
# Index(['Area2011', 'Area2012', 'Area2013', 'Area2014', 'Area2015', 'Yield2011',
#        'Yield2012', 'Yield2013', 'Yield2014', 'Yield2015'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X.columns,columns=['Coeff'])

# %%
cdf
# Out:
#               Coeff
# Area2011   0.110921
# Area2012  -0.722236
# Area2013   0.321524
# Area2014  -0.073055
# Area2015   1.681248
# Yield2011 -0.011890
# Yield2012  0.528111
# Yield2013 -0.028701
# Yield2014 -0.209330
# Yield2015  0.840778

# %% [markdown]
# # (2) Using Decision Trees & Random Forests Algorithm  --:
#
#    ##  (i) Decision Trees **
#
# ## Training and Testing Data
#
# Now that we've explored the data a bit, let's go ahead and split the data into training and testing sets.
# ** Set a variable X equal to the numerical features area & Year and a variable y equal to the "Production" column. **

# %%
data_agri.drop(['Crop','Season'],axis=1,inplace=True)                             # Drop two columns having datatype string

# %%
data_agri.columns
# Out:
# Index(['Prod2011', 'Prod2012', 'Prod2013', 'Prod2014', 'Prod2015', 'Area2011',
#        'Area2012', 'Area2013', 'Area2014', 'Area2015', 'Yield2011',
#        'Yield2012', 'Yield2013', 'Yield2014', 'Yield2015', 'Weather'],
#       dtype='object')

# %%
X = data_agri.drop('Weather',axis=1)

# %%
y = data_agri['Weather']

# %% [markdown]
# ** Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size=0.3 and random_state=101**

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ## Training the Model
#
# Now its time to train our model on our training data!
#
# ** Import DecisionTreeClassifier from sklearn.tree **

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Create an instance of a DecisionTreeClassifier() model named dtree.**

# %%
dtree = DecisionTreeClassifier()

# %% [markdown]
# ## Train/fit dtree on the training data.

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %% [markdown]
# ## Predicting Test Data
# Now that we have fit our model, let's evaluate its performance by predicting off the test values!
#
# ** Use dtree.predict() to predict off the X_test set of the data.**

# %%
predictions = dtree.predict(X_test)

# %% [markdown]
# ### classification report for model

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[1 3 0]
#  [1 3 0]
#  [1 5 3]]
#
#
#               precision    recall  f1-score   support
#
#    Overcast        0.33      0.25      0.29         4
#        Rainy       0.27      0.75      0.40         4
#        Sunny       1.00      0.33      0.50         9
#
#     accuracy                           0.41        17
#    macro avg       0.54      0.44      0.40        17
# weighted avg       0.67      0.41      0.43        17

# %% [markdown]
# ### Create a scatterplot of the real test values versus the predicted values.

# %%
plt.scatter(y_test,prediction)
plt.xlabel('Y_test')                        
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %% [markdown]
# ##  (ii) Random Forests Algorithm **
#
# ## Training the Model
#
# Now its time to train our model on our training data!
#
# ** Import RandomForestClassifier from sklearn.ensemble **

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# **Create an instance of a RandomForestClassifier() model named rfc.**

# %%
rfc = RandomForestClassifier(n_estimators=151)

# %% [markdown]
# ## Train/fit lm on the training data.

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=151,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# ## Predicting Test Data
# Now that we have fit our model, let's evaluate its performance by predicting off the test values!
#
# ** Use rfc_pred.predict() to predict off the X_test set of the data.**

# %%
rfc_pred = rfc.predict(X_test)

# %% [markdown]
# ### Classification report for model

# %%
print(confusion_matrix(y_test,rfc_pred))
print('\n')
print(classification_report(y_test,rfc_pred))
# Out:
# [[3 1 0]
#  [2 2 0]
#  [0 6 3]]
#
#
#               precision    recall  f1-score   support
#
#    Overcast        0.60      0.75      0.67         4
#        Rainy       0.22      0.50      0.31         4
#        Sunny       1.00      0.33      0.50         9
#
#     accuracy                           0.47        17
#    macro avg       0.61      0.53      0.49        17
# weighted avg       0.72      0.47      0.49        17

# %% [markdown]
# # (3) Using Logistic Regression  --:
#
# ## Training and Testing Data
#
# Now that we've explored the data a bit, let's go ahead and split the data into training and testing sets.
# ** Set a variable X equal to the numerical features area & Year and a variable y equal to the "Production" column. **

# %%
data_agri.shape
# Out:
# (54, 18)

# %%
Season = pd.get_dummies(data_agri['Season'])

# %%
Weather = pd.get_dummies(data_agri['Weather'])

# %%
data_agri = pd.concat([data_agri,Weather,Season],axis=1)

# %%
data_agri.head(2)
# Out:
#                Crop  Prod2011  Prod2012  Prod2013  Prod2014  Prod2015  \
# 0  Total Foodgrains     158.8     168.6     171.3     159.4     178.9
# 1              Rice     200.8     207.9     213.3     191.6     206.4
#
#    Area2011  Area2012  Area2013  Area2014  ...  Yield2013  Yield2014  \
# 0     128.5     128.8     127.6     126.0  ...      134.3      126.5
# 1     168.5     168.9     175.1     161.2  ...      121.8      118.9
#
#    Yield2015    Weather  Season  Overcast  Rainy Sunny  Kharif  Rabi
# 0      135.9      Rainy  Kharif          0     1     0       1     0
# 1      125.2  Overcast     Rabi          1     0     0       0     1
#
# [2 rows x 23 columns]

# %%
data_agri.drop(['Season','Crop','Weather'],axis=1,inplace=True)

# %%
data_agri.head()
# Out:
#    Prod2011  Prod2012  Prod2013  Prod2014  Prod2015  Area2011  Area2012  \
# 0     158.8     168.6     171.3    159.40     178.9     128.5     128.8
# 1     200.8     207.9     213.3    191.60     206.4     168.5     168.9
# 2     131.6     136.4     140.1    140.30     150.8     115.0     115.2
# 3     124.3     137.8     126.0    116.50     121.8     120.7     110.6
# 4     136.4     161.5     143.9    146.95     167.9      94.5      95.1
#
#    Area2013  Area2014  Area2015  Yield2011  Yield2012  Yield2013  Yield2014  \
# 0     127.6     126.0     131.7      123.6      130.9      134.3      126.5
# 1     175.1     161.2     164.8      119.2      123.1      121.8      118.9
# 2     114.0     116.9     119.5      114.4      118.4      122.8      120.0
# 3     107.3     111.0     105.2      103.0      124.6      117.4      105.0
# 4      87.0      88.5      95.6      144.3      169.7      165.4      119.0
#
#    Yield2015  Overcast   Rainy  Sunny  Kharif  Rabi
# ...

# %%
X =data_agri.drop('Kharif',axis=1)

# %%
y = data_agri['Kharif']

# %% [markdown]
# ** Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size=0.3 and random_state=101**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ## Training the Model
#
# Now its time to train our model on our training data!
#
# ** Import LogisticRegression from sklearn.linear_model **

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# **Create an instance of a LogisticRegression() model named logmodle.**

# %%
logmodle = LogisticRegression()

# %% [markdown]
# ## Train/fit logmodel on the training data.

# %%
logmodle.fit(X_train,y_train)
# Out:
# C:\Users\Nimish\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ## Predicting Test Data
# Now that we have fit our model, let's evaluate its performance by predicting off the test values!
#
# ** Use logmodel.predict() to predict off the X_test set of the data.**

# %%
pred = logmodle.predict(X_test)

# %% [markdown]
# ### Classification report for model

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        11
#            1       0.67      0.67      0.67         6
#
#     accuracy                           0.76        17
#    macro avg       0.74      0.74      0.74        17
# weighted avg       0.76      0.76      0.76        17

# %% [markdown]
# ### Create a scatterplot of the real test values versus the predicted values.

# %%
sns.distplot((y_test-pred))

# %% [markdown]
# # (3) Using K Nearest Neighbours  --:
#
# ## Standardize the Variables
#
# Time to standardize the variables.
#
# ** Import StandardScaler from Scikit learn.**

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ** Create a StandardScaler() object called scaler.**

# %%
scaler = StandardScaler()

# %%
Season= pd.get_dummies(data_agri['Season'],drop_first=True)

# %%
data_agri =pd.concat([data_agri,Season],axis =1)

# %%
data_agri.head(2)
# Out:
#                Crop  Prod2011  Prod2012  Prod2013  Prod2014  Prod2015  \
# 0  Total Foodgrains     158.8     168.6     171.3     159.4     178.9
# 1              Rice     200.8     207.9     213.3     191.6     206.4
#
#    Area2011  Area2012  Area2013  Area2014  Area2015  Yield2011  Yield2012  \
# 0     128.5     128.8     127.6     126.0     131.7      123.6      130.9
# 1     168.5     168.9     175.1     161.2     164.8      119.2      123.1
#
#    Yield2013  Yield2014  Yield2015    Weather  Season  Rabi
# 0      134.3      126.5      135.9      Rainy  Kharif     0
# 1      121.8      118.9      125.2  Overcast     Rabi     1

# %%
data_agri.drop(['Season','Crop','Weather'],axis=1,inplace=True)

# %%
data_agri.head(2)
# Out:
#    Prod2011  Prod2012  Prod2013  Prod2014  Prod2015  Area2011  Area2012  \
# 0     158.8     168.6     171.3     159.4     178.9     128.5     128.8
# 1     200.8     207.9     213.3     191.6     206.4     168.5     168.9
#
#    Area2013  Area2014  Area2015  Yield2011  Yield2012  Yield2013  Yield2014  \
# 0     127.6     126.0     131.7      123.6      130.9      134.3      126.5
# 1     175.1     161.2     164.8      119.2      123.1      121.8      118.9
#
#    Yield2015  Rabi
# 0      135.9     0
# 1      125.2     1

# %% [markdown]
# ** Fit scaler to the features.**

# %%
scaler.fit(data_agri.drop('Rabi',axis = 1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# **Use the .transform() method to transform the features to a scaled version.**

# %%
scaled_features = scaler.transform(data_agri.drop('Rabi',axis=1))

# %% [markdown]
# **Convert the scaled features to a dataframe and check the head of this dataframe to make sure the scaling worked.**

# %%
df_feat = pd.DataFrame(scaled_features,columns=data_agri.columns[:-1])
df_feat.head()
# Out:
#    Prod2011  Prod2012  Prod2013  Prod2014  Prod2015  Area2011  Area2012  \
# 0  0.278287  0.198015  0.236739  0.107683 -0.024147  0.330987  0.255244
# 1  1.149445  0.863668  0.894895  0.622074  0.305429  1.384060  1.226777
# 2 -0.285892 -0.347381 -0.252177 -0.197438 -0.360914 -0.024425 -0.074254
# 3 -0.437308 -0.323668 -0.473130 -0.577640 -0.708466  0.125638 -0.185701
# 4 -0.186331  0.077757 -0.192630 -0.091205 -0.155977 -0.564126 -0.561232
#
#    Area2013  Area2014  Area2015  Yield2011  Yield2012  Yield2013  Yield2014  \
# 0  0.161512  0.174917  0.084947  -0.133111  -0.086625   0.118676  -0.064284
# 1  1.230065  0.957599  0.688658  -0.273927  -0.344844  -0.307875  -0.314591
# 2 -0.144432 -0.027424 -0.137569  -0.427544  -0.500437  -0.273751  -0.278363
# 3 -0.295154 -0.158612 -0.398387  -0.792384  -0.295186  -0.458021  -0.772389
# 4 -0.751820 -0.658905 -0.573482   0.529362   1.197850   1.179935  -0.311298
#
#    Yield2015
# 0  -0.222823
# 1  -0.543089
# 2  -0.510165
# 3  -0.824445
# ...

# %% [markdown]
# ## Train Test Split
#
# **Use train_test_split to split your data into a training set and a testing set.**

# %%
from sklearn.model_selection import train_test_split

# %%
X = data_agri
y=data_agri['Rabi']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Using KNN
#
# **Import KNeighborsClassifier from scikit learn.**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# **Create a KNN model instance with n_neighbors=1**

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# **Fit this KNN model to the training data.**

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %% [markdown]
# ## Predictions and Evaluations
# Let's evaluate our KNN model!

# %% [markdown]
# **Use the predict method to predict values using your KNN model and X_test.**

# %%
pred = knn.predict(X_test)

# %% [markdown]
# ** Create a confusion matrix and classification report.**

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[4 2]
#  [7 4]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.67      0.47         6
#            1       0.67      0.36      0.47        11
#
#     accuracy                           0.47        17
#    macro avg       0.52      0.52      0.47        17
# weighted avg       0.56      0.47      0.47        17

# %% [markdown]
# # Choosing a K Value
# Let's go ahead and use the elbow method to pick a good K Value!
#
# ** Create a for loop that trains various KNN models with different k values, then keep track of the error_rate for each of these models with a list. Refer to the lecture if you are confused on this step.**

# %%
error_rate = []

for i in range(1,40):
    knn =KNeighborsClassifier(n_neighbors=1)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %% [markdown]
# **Now create the following plot using the information from your for loop.**

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# ## Retrain with new K Value
#
# **Retrain your model with the best K value (up to you to decide what you want) and re-do the classification report and the confusion matrix.**

# %%
# NOW WITH K=30
knn = KNeighborsClassifier(n_neighbors=30)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print('WITH K=30')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# WITH K=30
#
#
# [[5 1]
#  [7 4]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.42      0.83      0.56         6
#            1       0.80      0.36      0.50        11
#
#     accuracy                           0.53        17
#    macro avg       0.61      0.60      0.53        17
# weighted avg       0.66      0.53      0.52        17
