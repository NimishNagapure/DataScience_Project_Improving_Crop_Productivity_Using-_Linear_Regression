# %%
import pandas as pd                    
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_agri = pd.read_csv('C:/Users/nimis/Desktop/project/New/apy.csv')

# %%
y=data_agri[data_agri.Production > 10000]

# %%
data_agri.drop([7],inplace=True)
def impute_median(series):
    return series.fillna(series.median())
data_agri.Production = data_agri['Production'].transform(impute_median)

# %%
sns.distplot(data_agri.Production)

# %%
sns.heatmap(data_agri.corr(),annot=True)

# %%
sns.pairplot(data_agri)

# %%
sns.distplot(data_agri['Production'])

# %%
data_agri.columns
# Out:
# Index(['District', 'Year', 'Season', 'Crop', 'Area', 'Production', 'Weather'], dtype='object')

# %%
X = data_agri[['Area']]

# %%
y = data_agri['Production']

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm.intercept_)
# Out:
# 280.27157376641856

# %%
lm.coef_
# Out:
# array([0.34370286])

# %%
X_train.columns
# Out:
# Index(['Area'], dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X.columns,columns=['Coeff'])

# %%
cdf
# Out:
#          Coeff
# Area  0.343703

# %% [markdown]
# # Prediction

# %%
prediction = lm.predict(X_test)

# %%
prediction
# Out:
# array([383.38243084, 417.75271653, 396.78684226, ..., 383.38243084,
#        349.01214515, 452.12300222])

# %%
y_test
# Out:
# 4439    100.0
# 3900    200.0
# 1967    400.0
# 3994    100.0
# 6638      1.0
#         ...
# 2980    900.0
# 5506    100.0
# 4297    200.0
# 5125      0.0
# 3632    200.0
# Name: Production, Length: 2687, dtype: float64

# %%
plt.scatter(y_test,prediction)

# %%
 sns.distplot((y_test-prediction))

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,prediction)
# Out:
# 241.77514505745623

# %%
metrics.mean_squared_error(y_test,prediction)
# Out:
# 81158.04743917241

# %%
np.sqrt(metrics.mean_squared_error(y_test,prediction))
# Out:
# 284.8825151517243
